# %%
import pandas as pd
import numpy as np

# %%
demographic_df = pd.read_csv("Demographic-2016-presidential-election-by-county.csv", error_bad_lines=False)
# Out:
# b'Skipping line 3: expected 46 fields, saw 51\nSkipping line 4: expected 46 fields, saw 231\nSkipping line 5: expected 46 fields, saw 778\nSkipping line 6: expected 46 fields, saw 118\nSkipping line 7: expected 46 fields, saw 546\nSkipping line 9: expected 46 fields, saw 819\nSkipping line 10: expected 46 fields, saw 2759\nSkipping line 11: expected 46 fields, saw 830\nSkipping line 12: expected 46 fields, saw 913\nSkipping line 13: expected 46 fields, saw 561\nSkipping line 14: expected 46 fields, saw 1152\nSkipping line 17: expected 46 fields, saw 66\nSkipping line 18: expected 46 fields, saw 522\nSkipping line 19: expected 46 fields, saw 284\nSkipping line 20: expected 46 fields, saw 131\nSkipping line 21: expected 46 fields, saw 654\nSkipping line 22: expected 46 fields, saw 361\nSkipping line 24: expected 46 fields, saw 1331\nSkipping line 25: expected 46 fields, saw 348\nSkipping line 26: expected 46 fields, saw 219\nSkipping line 27: expected 46 fields, saw 151\nSkipping line 
# ...
