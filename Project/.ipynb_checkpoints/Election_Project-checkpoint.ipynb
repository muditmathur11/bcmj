# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# DATA WRANGLING - CLEAN ELECTION DATA US ELECTION 2012

# %%
#Read in csv file
df = pd.read_csv("election_data.csv")

#Filter for 2012 and 2016
df_2012 = df[df["year"] == 2012]
df_2016 = df[df["year"] == 2016]
df_2016.columns
# Out:
# Index(['year', 'state', 'state_po', 'county', 'FIPS', 'office', 'candidate',
#        'party', 'candidatevotes', 'totalvotes', 'version'],
#       dtype='object')

# %%
#Create pivot table with candidates as columns and votes as vales
pivot_2012 = df_2012.pivot(columns = "candidate", values = "candidatevotes")

#Merge pivot table with original 2012 dataframe
merged_2012 = df_2012.merge(pivot_2012, right_index=True, left_index=True)

#Group by state and county and sum (this allows all votes to be on same row)
merged_grouped_2012 = merged_2012.groupby(["state", "state_po", "county"]).sum()

#Select last three rows and transform to ints
election_2012 = merged_grouped_2012.iloc[:,-3:].astype(int)

#Create total votes column
election_2012["Total Votes"] = election_2012.sum(1)

#Create column for winner and margin of victory
election_2012["Winner"] = np.where(election_2012['Barack Obama']>election_2012["Mitt Romney"], 'Barack Obama', 'Mitt Romney')
election_2012["Margin"] = np.where(election_2012["Winner"]=="Mitt Romney", 
                                   election_2012["Mitt Romney"]-election_2012["Barack Obama"],
                                   election_2012["Barack Obama"]-election_2012["Mitt Romney"])
#Preview results
election_2012.head(10)
# Out:
#                            Barack Obama  Mitt Romney  Other  Total Votes  \
# state   state_po county
# Alabama AL       Autauga           6363        17379    190        23932
#                  Baldwin          18424        66016    898        85338
#                  Barbour           5912         5550     47        11509
#                  Bibb              2202         6132     86         8420
#                  Blount            2970        20757    279        24006
#                  Bullock           4061         1251     10         5322
#                  Butler            4374         5087     35         9496
#                  Calhoun          15511        30278    468        46257
#                  Chambers          6871         7626    114        14611
#                  Cherokee          2132         7506    141         9779
#
#                                  Winner  Margin
# state   state_po county
# Alabama AL       Autauga    Mitt Romney   11016
#                  Baldwin    Mitt Romney   47592
#                  Barbour   Barack Obama     362
#                  Bibb       Mitt Romney    3930
#                  Blount     Mitt Romney   17787
#                  Bullock   Barack Obama    2810
#                  Butler     Mitt Romney     713
#                  Calhoun    Mitt Romney   14767
#                  Chambers   Mitt Romney     755
#                  Cherokee   Mitt Romney    5374

# %% [markdown]
# GRAPH 1 - PIE CHART - ELECTION DATA US ELECTION 2012

# %%
#Find total votes for Barack Obama 2012
obama_total = election_2012["Barack Obama"].sum()

#Find total votes for Mitt Romney 2012
romney_total = election_2012["Mitt Romney"].sum()

#Find total votes for Other 2012
other_2012_total = election_2012["Other"].sum()

# %%
#Add labels
labels_2012 = ["Barack Obama", "Mitt Romney", "Other"]

#Add title
plt.title("% of Total Votes Presidential Election 2012")

#Set the values of each section of the pie chart
sizes_2012 = [obama_total, romney_total, other_2012_total]

#Set the colors of each section of the pie chart
colors_2012 = ["#0e87cc", "firebrick", "lightgray" ]

# Create the pie chart based upon the values above
plt.pie(sizes_2012, labels=labels_2012, colors=colors_2012,
        autopct="%1.1f%%", shadow=True, startangle=100)

#Show pie chart
plt.show()

# %% [markdown]
# DATA WRANGLING - CLEAN ELECTION DATA US ELECTION 2016

# %%
#Create pivot table with candidates as columns and votes as vales
pivot_2016 = df_2016.pivot(columns = "candidate", values = "candidatevotes")

#Merge pivot table with original 2016 dataframe
merged_2016 = df_2016.merge(pivot_2016, right_index=True, left_index=True)

#Group by state and county and sum (this allows all votes to be on same row)
merged_grouped_2016 = merged_2016.groupby(["state","state_po", "county"]).sum()

#Select last three rows and transform to ints
election_2016 = merged_grouped_2016.iloc[:,-3:].astype(int)

#Create total votes column
election_2016["Total Votes"] = election_2016.sum(1)

#Create column for winner and margin of victory
election_2016["Winner"] = np.where(election_2016['Hillary Clinton']>election_2016["Donald Trump"], 'Hillary Clinton', 'Donald Trump')
election_2016["Margin"] = np.where(election_2016["Winner"]=="Donald Trump", 
                                   election_2016["Donald Trump"]-election_2016["Hillary Clinton"],
                                   election_2016["Hillary Clinton"]-election_2016["Donald Trump"])
#Preview results
election_2016.head(10)
# Out:
#                            Donald Trump  Hillary Clinton  Other  Total Votes  \
# state   state_po county
# Alabama AL       Autauga          18172             5936    865        24973
#                  Baldwin          72883            18458   3874        95215
#                  Barbour           5454             4871    144        10469
#                  Bibb              6738             1874    207         8819
#                  Blount           22859             2156    573        25588
#                  Bullock           1140             3530     40         4710
#                  Butler            4901             3726    105         8732
#                  Calhoun          32865            13242   1757        47864
#                  Chambers          7843             5784    273        13900
#                  Cherokee          8953             1547    233        10733
#
#                                     Winner  Margin
# state   state_po county
# Alabama AL       Autauga      Donald Trump   12236
#                  Baldwin      Donald Trump   54425
#                  Barbour      Donald Trump     583
#                  Bibb         Donald Trump    4864
#                  Blount       Donald Trump   20703
#                  Bullock   Hillary Clinton    2390
#                  Butler       Donald Trump    1175
#                  Calhoun      Donald Trump   19623
#                  Chambers     Donald Trump    2059
#                  Cherokee     Donald Trump    7406

# %% [markdown]
# GRAPH 2 - PIE CHART - ELECTION DATA US ELECTION 2016

# %%
#Find total votes for Donald Trump 2016
trump_total = election_2016["Donald Trump"].sum()

#Find total votes for Hillary Clinton 2016
clinton_total = election_2016["Hillary Clinton"].sum()

#Find total votes for Other 2016
other_2016_total = election_2016["Other"].sum()

# %%
#Add labels
labels_2016 = ["Donald Trump", "Hillary Clinton", "Other"]

#Add title
plt.title("% of Total Votes Presidential Election 2016")

#Set the values of each section of the pie chart
sizes_2016 = [trump_total, clinton_total, other_2016_total]

#Set the colors of each section of the pie chart
colors_2016 = ["firebrick", "#0e87cc", "lightgray" ]

# Create the pie chart based upon the values above
plt.pie(sizes_2016, labels=labels_2016, colors=colors_2016,
        autopct="%1.1f%%", shadow=True, startangle=100)

#Show pie chart
plt.show()

# %% [markdown]
# DATA MERGE | US ELECTION 2012 & US ELECTION 2016

# %%
#Join 2012 and 2016 dataframes
election_df = election_2012.join(election_2016, rsuffix = "_2016", lsuffix="_2012")

#Create column for percent change between total votes in 2012 and 2016
election_df["Total_Votes_Percent_Change"] = round((election_df["Total Votes_2016"] - election_df["Total Votes_2012"]) / election_df["Total Votes_2012"] * 100,2)

#Show results
election_df.head(10)

#export as CSV
election_df.reset_index().to_csv("2012_2016_election.csv")

# %% [markdown]
# GRAPH 3: BAR CHART ON MERGED ELECTION DATA 2012 2016

# %%
republican = (romney_total, trump_total)
democratic = (obama_total, clinton_total)
other = (other_2012_total, other_2016_total)

#The x locations for the groups
ind = np.arange(len(democratic)) 

#The width of the bars
width = 0.15  

#Create the bars
fig, ax = plt.subplots()
rects1 = plt.bar(ind - width, republican, width, label='Republican', color="firebrick")
rects2 = plt.bar(ind + width/9, democratic, width, label='Democratic', color="#0e87cc")
rects3 = plt.bar(ind + width*1.2, other, width, label='Other', color="lightgray")

# Add some text for labels, title
plt.ylabel('Votes (10 millions)')
plt.title('Votes per Parties 2012 and 2016')

#Add legend
plt.legend(loc= "upper center")

#Add grid
plt.grid(alpha= 0.3)

#Set ticks
plt.xticks(ind)

#Add tick labels
ax.set_xticklabels(('2012', '2016'))

#Show bar chart
plt.show()

# %%
#Store number of counties that changed parties between 2012 and 2016
#dem_rep_df = pd.DataFrame(election_df[(election_df.Winner_2012 == "Barack Obama") & (election_df.Winner_2016 == "Donald Trump")])

Dem_Rep = len(election_df[(election_df.Winner_2012 == "Barack Obama") & (election_df.Winner_2016 == "Donald Trump")])
Rep_Dem = len(election_df[(election_df.Winner_2012 == "Mitt Romney") & (election_df.Winner_2016 == "Hillary Clinton")])

# %% [markdown]
# DATA WRANGLING - CLEAN ELECTION DEMOGRAPHIC DATA

# %%
#Read in demographic data
demo_df = pd.read_csv("demographic_data.csv")

#Split data in county on the comma, replace "county" with ""
demo_df['county'] = demo_df['county'].str.split(',').str[0]
demo_df["county"] = demo_df.county.str.replace(" County", "",)

#Group data, export if necessary
grouped_demo = demo_df.groupby(["state", "county"]).sum()
#grouped_demo.reset_index().to_csv("grouped_demo.csv")

#Read in income and poverty data
income_df = pd.read_csv("income_data.csv")

#Replace "Parish" with ""
income_df["Name"] = income_df.Name.str.replace(" Parish", "")

#Replace "County" with ""
income_df["Name"] = income_df.Name.str.replace(" County", "")

#Replace "city" with ""
income_df["Name"] = income_df.Name.str.replace(" city", "")

income_df = income_df[["Postal Code", "Name", "Poverty Percent, All Ages", "Median Household Income"]]

income_df.head()
# Out:
#   Postal Code          Name Poverty Percent, All Ages Median Household Income
# 0          HI       Kalawao                         .                       .
# 1          VA       Loudoun                       3.0                 136,191
# 2          VA  Falls Church                       3.4                 123,923
# 3          CA   Santa Clara                       7.5                 118,468
# 4          NM    Los Alamos                       3.7                 118,380

# %%
#Read in clean data
election = pd.read_csv("2012_2016_election.csv")
demographics = pd.read_csv("demo_clean.csv")

#Replace "Parish" with ""
demographics["county"] = demographics.county.str.replace(" Parish", "")

# %% [markdown]
# DATA MERGE | US ELECTION 2012 2016 X DEMOGRAPHIC

# %%
#Merge dataframes
election_merged = pd.merge(election, demographics)
#election_merged = pd.merge(election_merged, income_df)

#Make new columns for dem/rep percent change
election_merged["Dem_Votes_Percent_Change"] = round((election_merged["Hillary Clinton"] - election_merged["Barack Obama"]) / election_merged["Barack Obama"] * 100,2)
election_merged["Rep_Votes_Percent_Change"] = round((election_merged["Donald Trump"] - election_merged["Mitt Romney"]) / election_merged["Mitt Romney"] * 100,2)

#dem_rep_df.reset_index(inplace=True)
election_merged.rename(columns={"state_po":"Postal Code"}, inplace=True)
income_df.rename(columns={"Name":"county"}, inplace=True)

election_merged = pd.merge(election_merged, income_df)
election_merged["Median Household Income"] = election_merged["Median Household Income"].str.replace(",","")
election_merged["Median Household Income"] = election_merged["Median Household Income"].astype("int")
election_merged["Poverty Percent, All Ages"] = election_merged["Poverty Percent, All Ages"].astype("float")

# %%
election_merged.rename(columns={"state_po":"Postal Code"}, inplace=True)

election_merged.T
# Out:
#                                                             0     \
# Unnamed: 0                                                     0
# state                                                    Alabama
# Postal Code                                                   AL
# county                                                   Autauga
# Barack Obama                                                6363
# Mitt Romney                                                17379
# Other_2012                                                   190
# Total Votes_2012                                           23932
# Winner_2012                                          Mitt Romney
# Margin_2012                                                11016
# Donald Trump                                               18172
# Hillary Clinton                                             5936
# Other_2016                                                   865
# Total Votes_2016                                           24973
# Winner_2016                                         Donald Trump
# Margin_2016                                                12236
# Total_Votes_Percent_Change                                  4.35
# median_age                                                  36.2
# unemployment                                               0.065
# total_population                                           52077
# graduate_degree                                              7.1
# at_least_bachelor_s_degree                                  21.7
# at_least_high_school_diploma                                85.3
# less_than_high_school                                       14.7
# median_earnings_2010_dollars                             30043.2
# white                                                      77.55
# black                                                       17.7
# hispanic                                                     2.2
# asian                                                       0.75
# farming_fishing_and_forestry_occupations                     0.5
# construction_extraction_maintenance_and_repair_...          11.2
# management_professional_and_related_occupations             29.4
# production_transportation_and_material_moving_o...         13.55
# sales_and_office_occupations                                28.9
# service_occupations                                        16.35
# Dem_Votes_Percent_Change                                   -6.71
# Rep_Votes_Percent_Change                                    4.56
# Poverty Percent, All Ages                                   13.4
# Median Household Income                                    58343
#
#                                                             1     \
# Unnamed: 0                                                     1
# state                                                    Alabama
# Postal Code                                                   AL
# county                                                   Baldwin
# Barack Obama                                               18424
# Mitt Romney                                                66016
# Other_2012                                                   898
# Total Votes_2012                                           85338
# Winner_2012                                          Mitt Romney
# Margin_2012                                                47592
# Donald Trump                                               72883
# Hillary Clinton                                            18458
# Other_2016                                                  3874
# Total Votes_2016                                           95215
# Winner_2016                                         Donald Trump
# Margin_2016                                                54425
# Total_Votes_Percent_Change                                 11.57
# median_age                                                    41
# unemployment                                               0.068
# total_population                                          177131
# graduate_degree                                              8.7
# at_least_bachelor_s_degree                                  26.8
# at_least_high_school_diploma                                87.6
# less_than_high_school                                       12.4
# median_earnings_2010_dollars                             26630.6
# white                                                       84.3
# black                                                       9.55
# hispanic                                                    3.65
# asian                                                       0.65
# farming_fishing_and_forestry_occupations                    0.85
# construction_extraction_maintenance_and_repair_...         12.35
# management_professional_and_related_occupations             31.1
# production_transportation_and_material_moving_o...          10.9
# sales_and_office_occupations                                27.4
# service_occupations                                         17.4
# Dem_Votes_Percent_Change                                    0.18
# Rep_Votes_Percent_Change                                    10.4
# Poverty Percent, All Ages                                   10.1
# Median Household Income                                    56607
#
#                                                             2     \
# Unnamed: 0                                                     2
# state                                                    Alabama
# Postal Code                                                   AL
# county                                                   Barbour
# Barack Obama                                                5912
# Mitt Romney                                                 5550
# Other_2012                                                    47
# Total Votes_2012                                           11509
# Winner_2012                                         Barack Obama
# Margin_2012                                                  362
# Donald Trump                                                5454
# Hillary Clinton                                             4871
# Other_2016                                                   144
# Total Votes_2016                                           10469
# Winner_2016                                         Donald Trump
# Margin_2016                                                  583
# Total_Votes_Percent_Change                                 -9.04
# median_age                                                    38
# unemployment                                               0.112
# total_population                                           28560
# graduate_degree                                                6
# at_least_bachelor_s_degree                                  13.5
# at_least_high_school_diploma                                71.9
# less_than_high_school                                       28.1
# median_earnings_2010_dollars                             20663.5
# white                                                       47.4
# black                                                       46.5
# hispanic                                                     4.7
# asian                                                       0.25
# farming_fishing_and_forestry_occupations                    2.05
# construction_extraction_maintenance_and_repair_...          8.95
# management_professional_and_related_occupations            26.15
# production_transportation_and_material_moving_o...          27.9
# sales_and_office_occupations                                20.1
# service_occupations                                         14.9
# Dem_Votes_Percent_Change                                  -17.61
# Rep_Votes_Percent_Change                                   -1.73
# Poverty Percent, All Ages                                   33.4
# Median Household Income                                    32490
#
#                                                             3     \
# Unnamed: 0                                                     3
# state                                                    Alabama
# Postal Code                                                   AL
# county                                                      Bibb
# Barack Obama                                                2202
# Mitt Romney                                                 6132
# Other_2012                                                    86
# Total Votes_2012                                            8420
# Winner_2012                                          Mitt Romney
# Margin_2012                                                 3930
# Donald Trump                                                6738
# Hillary Clinton                                             1874
# Other_2016                                                   207
# Total Votes_2016                                            8819
# Winner_2016                                         Donald Trump
# Margin_2016                                                 4864
# Total_Votes_Percent_Change                                  4.74
# median_age                                                  38.3
# unemployment                                               0.076
# total_population                                           22189
# graduate_degree                                              2.6
# at_least_bachelor_s_degree                                    10
# at_least_high_school_diploma                                74.5
# less_than_high_school                                       25.5
# median_earnings_2010_dollars                               26875
# white                                                       75.2
# black                                                       22.5
# hispanic                                                    1.35
# asian                                                       0.15
# farming_fishing_and_forestry_occupations                     0.6
# construction_extraction_maintenance_and_repair_...         18.05
# management_professional_and_related_occupations            20.25
# production_transportation_and_material_moving_o...            25
# sales_and_office_occupations                               22.65
# service_occupations                                        13.55
# Dem_Votes_Percent_Change                                   -14.9
# Rep_Votes_Percent_Change                                    9.88
# Poverty Percent, All Ages                                   20.2
# Median Household Income                                    45795
#
#                                                             4     \
# Unnamed: 0                                                     4
# state                                                    Alabama
# Postal Code                                                   AL
# county                                                    Blount
# Barack Obama                                                2970
# Mitt Romney                                                20757
# Other_2012                                                   279
# Total Votes_2012                                           24006
# Winner_2012                                          Mitt Romney
# Margin_2012                                                17787
# Donald Trump                                               22859
# Hillary Clinton                                             2156
# Other_2016                                                   573
# Total Votes_2016                                           25588
# Winner_2016                                         Donald Trump
# Margin_2016                                                20703
# Total_Votes_Percent_Change                                  6.59
# median_age                                                  38.3
# unemployment                                               0.062
# total_population                                           57063
# graduate_degree                                              4.2
# at_least_bachelor_s_degree                                  12.5
# at_least_high_school_diploma                                74.7
# less_than_high_school                                       25.3
# median_earnings_2010_dollars                             27774.2
# white                                                      89.15
# black                                                       1.05
# hispanic                                                     7.7
# asian                                                        0.3
# farming_fishing_and_forestry_occupations                     1.2
# construction_extraction_maintenance_and_repair_...         15.85
# management_professional_and_related_occupations             24.1
# production_transportation_and_material_moving_o...          17.9
# sales_and_office_occupations                                24.8
# service_occupations                                        16.15
# Dem_Votes_Percent_Change                                  -27.41
# Rep_Votes_Percent_Change                                   10.13
# Poverty Percent, All Ages                                   12.8
# Median Household Income                                    48253
#
#                                                                5     \
# Unnamed: 0                                                        5
# state                                                       Alabama
# Postal Code                                                      AL
# county                                                      Bullock
# Barack Obama                                                   4061
# Mitt Romney                                                    1251
# Other_2012                                                       10
# Total Votes_2012                                               5322
# Winner_2012                                            Barack Obama
# Margin_2012                                                    2810
# Donald Trump                                                   1140
# Hillary Clinton                                                3530
# Other_2016                                                       40
# Total Votes_2016                                               4710
# Winner_2016                                         Hillary Clinton
# Margin_2016                                                    2390
# Total_Votes_Percent_Change                                    -11.5
# median_age                                                     38.7
# unemployment                                                  0.134
# total_population                                              10915
# graduate_degree                                                 3.7
# at_least_bachelor_s_degree                                       12
# at_least_high_school_diploma                                   74.7
# less_than_high_school                                          25.3
# median_earnings_2010_dollars                                20651.7
# white                                                         22.05
# black                                                         72.45
# hispanic                                                        4.7
# asian                                                          0.25
# farming_fishing_and_forestry_occupations                       5.15
# construction_extraction_maintenance_and_repair_...             7.75
# management_professional_and_related_occupations               19.05
# production_transportation_and_material_moving_o...            29.05
# sales_and_office_occupations                                  23.55
# service_occupations                                           15.45
# Dem_Votes_Percent_Change                                     -13.08
# Rep_Votes_Percent_Change                                      -8.87
# Poverty Percent, All Ages                                      34.4
# Median Household Income                                       29113
#
#                                                             6     \
# Unnamed: 0                                                     6
# state                                                    Alabama
# Postal Code                                                   AL
# county                                                    Butler
# Barack Obama                                                4374
# Mitt Romney                                                 5087
# Other_2012                                                    35
# Total Votes_2012                                            9496
# Winner_2012                                          Mitt Romney
# Margin_2012                                                  713
# Donald Trump                                                4901
# Hillary Clinton                                             3726
# Other_2016                                                   105
# Total Votes_2016                                            8732
# Winner_2016                                         Donald Trump
# Margin_2016                                                 1175
# Total_Votes_Percent_Change                                 -8.05
# median_age                                                  39.7
# unemployment                                               0.109
# total_population                                           20568
# graduate_degree                                              3.2
# at_least_bachelor_s_degree                                    11
# at_least_high_school_diploma                                74.8
# less_than_high_school                                       25.2
# median_earnings_2010_dollars                             22321.8
# white                                                       55.4
# black                                                      42.25
# hispanic                                                    0.65
# asian                                                        0.7
# farming_fishing_and_forestry_occupations                     2.1
# construction_extraction_maintenance_and_repair_...           9.6
# management_professional_and_related_occupations             21.5
# production_transportation_and_material_moving_o...         23.45
# sales_and_office_occupations                               26.55
# service_occupations                                        16.85
# Dem_Votes_Percent_Change                                  -14.81
# Rep_Votes_Percent_Change                                   -3.66
# Poverty Percent, All Ages                                   21.3
# Median Household Income                                    36842
#
#                                                             7     \
# Unnamed: 0                                                     7
# state                                                    Alabama
# Postal Code                                                   AL
# county                                                   Calhoun
# Barack Obama                                               15511
# Mitt Romney                                                30278
# Other_2012                                                   468
# Total Votes_2012                                           46257
# Winner_2012                                          Mitt Romney
# Margin_2012                                                14767
# Donald Trump                                               32865
# Hillary Clinton                                            13242
# Other_2016                                                  1757
# Total Votes_2016                                           47864
# Winner_2016                                         Donald Trump
# Margin_2016                                                19623
# Total_Votes_Percent_Change                                  3.47
# median_age                                                  38.1
# unemployment                                               0.076
# total_population                                          115770
# graduate_degree                                              6.4
# at_least_bachelor_s_degree                                  16.1
# at_least_high_school_diploma                                78.5
# less_than_high_school                                       21.5
# median_earnings_2010_dollars                             24610.5
# white                                                      74.65
# black                                                       19.9
# hispanic                                                    2.85
# asian                                                       0.75
# farming_fishing_and_forestry_occupations                    0.45
# construction_extraction_maintenance_and_repair_...         11.65
# management_professional_and_related_occupations             28.3
# production_transportation_and_material_moving_o...          20.3
# sales_and_office_occupations                               23.55
# service_occupations                                        15.75
# Dem_Votes_Percent_Change                                  -14.63
# Rep_Votes_Percent_Change                                    8.54
# Poverty Percent, All Ages                                   17.7
# Median Household Income                                    45937
#
#                                                             8     \
# Unnamed: 0                                                     8
# state                                                    Alabama
# Postal Code                                                   AL
# county                                                  Chambers
# Barack Obama                                                6871
# Mitt Romney                                                 7626
# Other_2012                                                   114
# Total Votes_2012                                           14611
# Winner_2012                                          Mitt Romney
# Margin_2012                                                  755
# Donald Trump                                                7843
# Hillary Clinton                                             5784
# Other_2016                                                   273
# Total Votes_2016                                           13900
# Winner_2016                                         Donald Trump
# Margin_2016                                                 2059
# Total_Votes_Percent_Change                                 -4.87
# median_age                                                  40.1
# unemployment                                               0.093
# total_population                                           34459
# graduate_degree                                              3.7
# at_least_bachelor_s_degree                                  10.8
# at_least_high_school_diploma                                71.8
# less_than_high_school                                       28.2
# median_earnings_2010_dollars                             23437.7
# white                                                      58.95
# black                                                      37.95
# hispanic                                                    1.45
# asian                                                       0.35
# farming_fishing_and_forestry_occupations                     0.4
# construction_extraction_maintenance_and_repair_...         12.55
# management_professional_and_related_occupations             22.4
# production_transportation_and_material_moving_o...         24.15
# sales_and_office_occupations                               26.15
# service_occupations                                        14.35
# Dem_Votes_Percent_Change                                  -15.82
# Rep_Votes_Percent_Change                                    2.85
# Poverty Percent, All Ages                                   18.2
# Median Household Income                                    36883
#
#                                                             9     ...  \
# Unnamed: 0                                                     9  ...
# state                                                    Alabama  ...
# Postal Code                                                   AL  ...
# county                                                  Cherokee  ...
# Barack Obama                                                2132  ...
# Mitt Romney                                                 7506  ...
# Other_2012                                                   141  ...
# Total Votes_2012                                            9779  ...
# Winner_2012                                          Mitt Romney  ...
# Margin_2012                                                 5374  ...
# Donald Trump                                                8953  ...
# Hillary Clinton                                             1547  ...
# Other_2016                                                   233  ...
# Total Votes_2016                                           10733  ...
# Winner_2016                                         Donald Trump  ...
# Margin_2016                                                 7406  ...
# Total_Votes_Percent_Change                                  9.76  ...
# median_age                                                  43.9  ...
# unemployment                                               0.071  ...
# total_population                                           25208  ...
# graduate_degree                                              4.2  ...
# at_least_bachelor_s_degree                                  10.5  ...
# at_least_high_school_diploma                                73.4  ...
# less_than_high_school                                       26.6  ...
# median_earnings_2010_dollars                             26915.9  ...
# white                                                         92  ...
# black                                                        5.1  ...
# hispanic                                                     1.2  ...
# asian                                                       0.15  ...
# farming_fishing_and_forestry_occupations                     1.4  ...
# construction_extraction_maintenance_and_repair_...         13.25  ...
# management_professional_and_related_occupations             24.6  ...
# production_transportation_and_material_moving_o...            25  ...
# sales_and_office_occupations                               20.25  ...
# service_occupations                                        15.55  ...
# Dem_Votes_Percent_Change                                  -27.44  ...
# Rep_Votes_Percent_Change                                   19.28  ...
# Poverty Percent, All Ages                                   17.2  ...
# Median Household Income                                    44842  ...
#
#                                                             3095  \
# Unnamed: 0                                                  3139
# state                                                    Wyoming
# Postal Code                                                   WY
# county                                                  Niobrara
# Barack Obama                                                 200
# Mitt Romney                                                 1022
# Other_2012                                                    54
# Total Votes_2012                                            1276
# Winner_2012                                          Mitt Romney
# Margin_2012                                                  822
# Donald Trump                                                1116
# Hillary Clinton                                              115
# Other_2016                                                    83
# Total Votes_2016                                            1314
# Winner_2016                                         Donald Trump
# Margin_2016                                                 1001
# Total_Votes_Percent_Change                                  2.98
# median_age                                                  45.2
# unemployment                                               0.041
# total_population                                            2395
# graduate_degree                                              5.6
# at_least_bachelor_s_degree                                  19.7
# at_least_high_school_diploma                                91.1
# less_than_high_school                                        8.9
# median_earnings_2010_dollars                             22404.2
# white                                                       92.2
# black                                                       0.55
# hispanic                                                     3.9
# asian                                                        0.2
# farming_fishing_and_forestry_occupations                     3.8
# construction_extraction_maintenance_and_repair_...         14.25
# management_professional_and_related_occupations             39.5
# production_transportation_and_material_moving_o...          10.6
# sales_and_office_occupations                               13.45
# service_occupations                                        18.25
# Dem_Votes_Percent_Change                                   -42.5
# Rep_Votes_Percent_Change                                     9.2
# Poverty Percent, All Ages                                   13.4
# Median Household Income                                    45768
#
#                                                             3096  \
# Unnamed: 0                                                  3140
# state                                                    Wyoming
# Postal Code                                                   WY
# county                                                      Park
# Barack Obama                                                2927
# Mitt Romney                                                11234
# Other_2012                                                   447
# Total Votes_2012                                           14608
# Winner_2012                                          Mitt Romney
# Margin_2012                                                 8307
# Donald Trump                                               11115
# Hillary Clinton                                             2535
# Other_2016                                                  1445
# Total Votes_2016                                           15095
# Winner_2016                                         Donald Trump
# Margin_2016                                                 8580
# Total_Votes_Percent_Change                                  3.33
# median_age                                                  43.9
# unemployment                                               0.058
# total_population                                           27699
# graduate_degree                                              9.4
# at_least_bachelor_s_degree                                  27.7
# at_least_high_school_diploma                                92.6
# less_than_high_school                                        7.4
# median_earnings_2010_dollars                             24150.1
# white                                                      92.95
# black                                                       0.15
# hispanic                                                    4.55
# asian                                                        0.6
# farming_fishing_and_forestry_occupations                    2.15
# construction_extraction_maintenance_and_repair_...         13.45
# management_professional_and_related_occupations             33.1
# production_transportation_and_material_moving_o...          10.8
# sales_and_office_occupations                               22.35
# service_occupations                                         18.1
# Dem_Votes_Percent_Change                                  -13.39
# Rep_Votes_Percent_Change                                   -1.06
# Poverty Percent, All Ages                                    9.4
# Median Household Income                                    57619
#
#                                                             3097  \
# Unnamed: 0                                                  3141
# state                                                    Wyoming
# Postal Code                                                   WY
# county                                                    Platte
# Barack Obama                                                1223
# Mitt Romney                                                 3136
# Other_2012                                                   172
# Total Votes_2012                                            4531
# Winner_2012                                          Mitt Romney
# Margin_2012                                                 1913
# Donald Trump                                                3437
# Hillary Clinton                                              719
# Other_2016                                                   373
# Total Votes_2016                                            4529
# Winner_2016                                         Donald Trump
# Margin_2016                                                 2718
# Total_Votes_Percent_Change                                 -0.04
# median_age                                                  46.4
# unemployment                                               0.057
# total_population                                            8505
# graduate_degree                                              6.6
# at_least_bachelor_s_degree                                  17.3
# at_least_high_school_diploma                                  89
# less_than_high_school                                         11
# median_earnings_2010_dollars                             23936.1
# white                                                       91.5
# black                                                       0.15
# hispanic                                                     6.5
# asian                                                        0.2
# farming_fishing_and_forestry_occupations                    6.55
# construction_extraction_maintenance_and_repair_...         11.45
# management_professional_and_related_occupations             27.4
# production_transportation_and_material_moving_o...         13.05
# sales_and_office_occupations                                20.7
# service_occupations                                        20.85
# Dem_Votes_Percent_Change                                  -41.21
# Rep_Votes_Percent_Change                                     9.6
# Poverty Percent, All Ages                                   10.4
# Median Household Income                                    50775
#
#                                                             3098  \
# Unnamed: 0                                                  3142
# state                                                    Wyoming
# Postal Code                                                   WY
# county                                                  Sheridan
# Barack Obama                                                3618
# Mitt Romney                                                10267
# Other_2012                                                   437
# Total Votes_2012                                           14322
# Winner_2012                                          Mitt Romney
# Margin_2012                                                 6649
# Donald Trump                                               10266
# Hillary Clinton                                             2927
# Other_2016                                                  1317
# Total Votes_2016                                           14510
# Winner_2016                                         Donald Trump
# Margin_2016                                                 7339
# Total_Votes_Percent_Change                                  1.31
# median_age                                                  43.1
# unemployment                                               0.061
# total_population                                           28589
# graduate_degree                                              7.6
# at_least_bachelor_s_degree                                  23.1
# at_least_high_school_diploma                                92.7
# less_than_high_school                                        7.3
# median_earnings_2010_dollars                             27724.9
# white                                                       93.3
# black                                                       0.15
# hispanic                                                    3.25
# asian                                                       0.55
# farming_fishing_and_forestry_occupations                    1.95
# construction_extraction_maintenance_and_repair_...            15
# management_professional_and_related_occupations             32.4
# production_transportation_and_material_moving_o...            12
# sales_and_office_occupations                                21.3
# service_occupations                                        17.35
# Dem_Votes_Percent_Change                                   -19.1
# Rep_Votes_Percent_Change                                   -0.01
# Poverty Percent, All Ages                                    9.1
# Median Household Income                                    54482
#
#                                                             3099  \
# Unnamed: 0                                                  3143
# state                                                    Wyoming
# Postal Code                                                   WY
# county                                                  Sublette
# Barack Obama                                                 767
# Mitt Romney                                                 3472
# Other_2012                                                   137
# Total Votes_2012                                            4376
# Winner_2012                                          Mitt Romney
# Margin_2012                                                 2705
# Donald Trump                                                3409
# Hillary Clinton                                              644
# Other_2016                                                   337
# Total Votes_2016                                            4390
# Winner_2016                                         Donald Trump
# Margin_2016                                                 2765
# Total_Votes_Percent_Change                                  0.32
# median_age                                                  39.5
# unemployment                                               0.037
# total_population                                            9024
# graduate_degree                                              6.4
# at_least_bachelor_s_degree                                  22.8
# at_least_high_school_diploma                                92.4
# less_than_high_school                                        7.6
# median_earnings_2010_dollars                             31177.9
# white                                                      92.15
# black                                                       0.15
# hispanic                                                    5.55
# asian                                                       0.25
# farming_fishing_and_forestry_occupations                     3.3
# construction_extraction_maintenance_and_repair_...          22.4
# management_professional_and_related_occupations             33.1
# production_transportation_and_material_moving_o...          13.5
# sales_and_office_occupations                               14.95
# service_occupations                                        12.75
# Dem_Votes_Percent_Change                                  -16.04
# Rep_Votes_Percent_Change                                   -1.81
# Poverty Percent, All Ages                                    6.6
# Median Household Income                                    74811
#
#                                                             3100  \
# Unnamed: 0                                                  3144
# state                                                    Wyoming
# Postal Code                                                   WY
# county                                                Sweetwater
# Barack Obama                                                4774
# Mitt Romney                                                11428
# Other_2012                                                   693
# Total Votes_2012                                           16895
# Winner_2012                                          Mitt Romney
# Margin_2012                                                 6654
# Donald Trump                                               12154
# Hillary Clinton                                             3231
# Other_2016                                                  1745
# Total Votes_2016                                           17130
# Winner_2016                                         Donald Trump
# Margin_2016                                                 8923
# Total_Votes_Percent_Change                                  1.39
# median_age                                                  33.1
# unemployment                                               0.046
# total_population                                           41473
# graduate_degree                                              4.6
# at_least_bachelor_s_degree                                  17.1
# at_least_high_school_diploma                                89.9
# less_than_high_school                                       10.1
# median_earnings_2010_dollars                             35123.3
# white                                                       82.3
# black                                                       0.75
# hispanic                                                    13.5
# asian                                                       0.65
# farming_fishing_and_forestry_occupations                     0.3
# construction_extraction_maintenance_and_repair_...         19.35
# management_professional_and_related_occupations            23.45
# production_transportation_and_material_moving_o...         18.55
# sales_and_office_occupations                                22.4
# service_occupations                                         15.9
# Dem_Votes_Percent_Change                                  -32.32
# Rep_Votes_Percent_Change                                    6.35
# Poverty Percent, All Ages                                     10
# Median Household Income                                    75590
#
#                                                                3101  \
# Unnamed: 0                                                     3145
# state                                                       Wyoming
# Postal Code                                                      WY
# county                                                        Teton
# Barack Obama                                                   6213
# Mitt Romney                                                    4858
# Other_2012                                                      393
# Total Votes_2012                                              11464
# Winner_2012                                            Barack Obama
# Margin_2012                                                    1355
# Donald Trump                                                   3921
# Hillary Clinton                                                7314
# Other_2016                                                     1392
# Total Votes_2016                                              12627
# Winner_2016                                         Hillary Clinton
# Margin_2016                                                    3393
# Total_Votes_Percent_Change                                    10.14
# median_age                                                     35.7
# unemployment                                                  0.066
# total_population                                              20680
# graduate_degree                                                16.4
# at_least_bachelor_s_degree                                     49.7
# at_least_high_school_diploma                                   95.1
# less_than_high_school                                           4.9
# median_earnings_2010_dollars                                33335.3
# white                                                         83.75
# black                                                           0.2
# hispanic                                                      13.65
# asian                                                             1
# farming_fishing_and_forestry_occupations                        0.8
# construction_extraction_maintenance_and_repair_...            11.85
# management_professional_and_related_occupations                34.5
# production_transportation_and_material_moving_o...              4.4
# sales_and_office_occupations                                  22.55
# service_occupations                                           25.85
# Dem_Votes_Percent_Change                                      17.72
# Rep_Votes_Percent_Change                                     -19.29
# Poverty Percent, All Ages                                       5.8
# Median Household Income                                       90145
#
#                                                             3102  \
# Unnamed: 0                                                  3146
# state                                                    Wyoming
# Postal Code                                                   WY
# county                                                     Uinta
# Barack Obama                                                1628
# Mitt Romney                                                 6615
# Other_2012                                                   296
# Total Votes_2012                                            8539
# Winner_2012                                          Mitt Romney
# Margin_2012                                                 4987
# Donald Trump                                                6154
# Hillary Clinton                                             1202
# Other_2016                                                  1114
# Total Votes_2016                                            8470
# Winner_2016                                         Donald Trump
# Margin_2016                                                 4952
# Total_Votes_Percent_Change                                 -0.81
# median_age                                                  34.2
# unemployment                                               0.051
# total_population                                           20618
# graduate_degree                                              5.1
# at_least_bachelor_s_degree                                  17.4
# at_least_high_school_diploma                                88.3
# less_than_high_school                                       11.7
# median_earnings_2010_dollars                             26890.8
# white                                                       89.1
# black                                                        0.1
# hispanic                                                    8.15
# asian                                                        0.2
# farming_fishing_and_forestry_occupations                     0.5
# construction_extraction_maintenance_and_repair_...         16.55
# management_professional_and_related_occupations            26.25
# production_transportation_and_material_moving_o...         17.55
# sales_and_office_occupations                                19.9
# service_occupations                                         19.2
# Dem_Votes_Percent_Change                                  -26.17
# Rep_Votes_Percent_Change                                   -6.97
# Poverty Percent, All Ages                                   10.2
# Median Household Income                                    67404
#
#                                                             3103          3104
# Unnamed: 0                                                  3147          3148
# state                                                    Wyoming       Wyoming
# Postal Code                                                   WY            WY
# county                                                  Washakie        Weston
# Barack Obama                                                 794           422
# Mitt Romney                                                 3014          2821
# Other_2012                                                   136           116
# Total Votes_2012                                            3944          3359
# Winner_2012                                          Mitt Romney   Mitt Romney
# Margin_2012                                                 2220          2399
# Donald Trump                                                2911          3033
# Hillary Clinton                                              532           299
# Other_2016                                                   371           194
# Total Votes_2016                                            3814          3526
# Winner_2016                                         Donald Trump  Donald Trump
# Margin_2016                                                 2379          2734
# Total_Votes_Percent_Change                                  -3.3          4.97
# median_age                                                  42.2          42.3
# unemployment                                               0.054         0.051
# total_population                                            8162          6986
# graduate_degree                                              8.9             4
# at_least_bachelor_s_degree                                  24.5          17.9
# at_least_high_school_diploma                                89.6          91.1
# less_than_high_school                                       10.4           8.9
# median_earnings_2010_dollars                             27096.9       34767.4
# white                                                       83.6         93.75
# black                                                        0.6           0.1
# hispanic                                                   13.85          2.85
# asian                                                       0.45          0.65
# farming_fishing_and_forestry_occupations                     3.4          1.65
# construction_extraction_maintenance_and_repair_...          17.4          27.6
# management_professional_and_related_occupations               30         27.75
# production_transportation_and_material_moving_o...          11.4          13.3
# sales_and_office_occupations                               21.05         15.45
# service_occupations                                         16.8         14.15
# Dem_Votes_Percent_Change                                     -33        -29.15
# Rep_Votes_Percent_Change                                   -3.42          7.52
# Poverty Percent, All Ages                                   10.7          10.6
# Median Household Income                                    57989         56214
#
# [39 rows x 3105 columns]

# %% [markdown]
# DATAFRAME FOR COUNTIES THAT SWITCHED PARTY COLOR

# %%
#Create dataframe for counties that switched
rep_dem_df = election_merged[(election_merged.Winner_2012 == "Mitt Romney") & (election_merged.Winner_2016 == "Hillary Clinton")]
dem_rep_df = election_merged[(election_merged.Winner_2012 == "Barack Obama") & (election_merged.Winner_2016 == "Donald Trump")]

total_count = election_merged.state.value_counts()
population = election_merged.groupby("state")["total_population"].sum()
switched_count = dem_rep_df.state.value_counts()

switch = pd.DataFrame({"switched": switched_count, "total":total_count, "population":population.apply(lambda x: f"{x:,.0f}")})
switch.dropna(inplace=True)
switch["%_Change"] = round(switch.switched / switch.total * 100,0)
switch.sort_values("switched", ascending=False, inplace=True)

switch.head(10)

#dem_rep_df.columns
#switch.max()
# Out:
#                 switched  total  population  %_Change
# Iowa                32.0    100   3,028,691      32.0
# Wisconsin           23.0     72   5,643,185      32.0
# New York            22.0     63  21,004,399      35.0
# Minnesota           18.0     85   5,040,446      21.0
# Michigan            12.0     83   9,961,406      14.0
# Illinois            11.0    101  12,694,701      11.0
# Ohio                 9.0     88  11,524,162      10.0
# Maine                8.0     16   1,322,366      50.0
# North Carolina       7.0    100   9,290,565       7.0
# Virginia             7.0    132   9,205,915       5.0

# %% [markdown]
# BINS FOR FORMATTING

# %%
age_bins = [0, 34, 40, 45, 100]
age_names = ["<35", "36-40", "41-45", "$46+"]
income_bins = [0, 34999, 45000, 55000, 65000, 75000, 200000]
income_names = ["<$35,000", "$35,001-$45,000", "$45,001-$55,000", "$55,001-$65,000", "$65,001-$75,000", "$75,001+"]

election_merged["Age Ranges"] = pd.cut(election_merged["median_age"], age_bins, labels = age_names)
election_merged["Median Income Ranges"] = pd.cut(election_merged["Median Household Income"], income_bins, labels = income_names)

# %%
#Create dataframe for counties that switched
#rep_dem_df = election_merged[(election_merged.Winner_2012 == "Mitt Romney") & (election_merged.Winner_2016 == "Hillary Clinton")]
#dem_rep_df = election_merged[(election_merged.Winner_2012 == "Barack Obama") & (election_merged.Winner_2016 == "Donald Trump")]

# %% [markdown]
# GRAPHS: HISTOGRAMS AND MAPS MERGED ELECTION DATA X DEMOGRAPHIC

# %%
parties_flipped = [Dem_Rep, Rep_Dem]

#The x location
x_axis = np.arange(len(parties_flipped))

#Create the bars
plt.bar(x_axis, parties_flipped, color=('firebrick','#0e87cc'), align="center",  width=0.3)

#Set ticks
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["Democratic -> Republican", "Republican -> Democratic"])

# Set the limits of the x axis
plt.xlim(-0.55, len(x_axis)-0.45)

#Add grid
plt.grid(alpha= 0.3)

#Add title and labels
plt.title("Total # of Counties that Flipped b/w Parties | Elections 2012 - 2016")
plt.ylabel("Number Of Counties")

#Show bar chart
plt.show()

# %%
switch_sum = dem_rep_df.sum()

percent_change_dem = round((switch_sum["Hillary Clinton"] - switch_sum["Barack Obama"]) / switch_sum["Barack Obama"] * 100, 2)
percent_change_rep = round((switch_sum["Donald Trump"] - switch_sum["Mitt Romney"]) / switch_sum["Mitt Romney"] * 100, 2)

print(f"{percent_change_dem}% decrease from Rep. to Dem.")
print(f"{percent_change_rep}% increase from Dem. to Rep.")
# Out:
# -13.85% decrease from Rep. to Dem.
# 18.08% increase from Dem. to Rep.

# %%
dem_rep_df["median_age"].plot(kind="hist", bins=25, alpha = 0.8, color = 'c', range =(20,60))
plt.xlabel("Median Age")
plt.ylabel("Number of Counties")
plt.title("Age distribution\nCounties than switched from Obama to Trump")
plt.vlines(dem_rep_df["median_age"].mean(), ymin=0,ymax=45,linestyles ="dashed")

# %%
election_merged["median_age"].plot(kind="hist", bins=25, alpha = 0.8, color = 'c')
plt.xlabel("Median Age")
plt.ylabel("Number of Counties")
plt.title("Age distribution\nAll Counties")
plt.vlines(election_merged["median_age"].mean(), ymin=0,ymax=550, linestyles ="dashed")

# %%
dem_rep_df['Poverty Percent, All Ages'].plot(kind="hist", bins=30, alpha = 0.8, color = 'y')
plt.xlabel("Poverty Percent, All Ages")
plt.ylabel("Number of Counties")
plt.title("Poverty Percent\nCounties than switched from Obama to Trump")
plt.vlines(dem_rep_df['Poverty Percent, All Ages'].mean(), ymin=0,ymax=45,linestyles ="dashed")

# %%
election_merged['Poverty Percent, All Ages'].plot(kind="hist", bins=30, alpha = 0.8, color = 'y')
plt.xlabel("Poverty Percent, All Ages")
plt.ylabel("Number of Counties")
plt.title("Poverty Percent\n All Counties")
plt.vlines(election_merged['Poverty Percent, All Ages'].mean(), ymin=0,ymax=450,linestyles ="dashed")

# %%
election_merged.columns
# Out:
# Index(['Unnamed: 0', 'state', 'Postal Code', 'county', 'Barack Obama',
#        'Mitt Romney', 'Other_2012', 'Total Votes_2012', 'Winner_2012',
#        'Margin_2012', 'Donald Trump', 'Hillary Clinton', 'Other_2016',
#        'Total Votes_2016', 'Winner_2016', 'Margin_2016',
#        'Total_Votes_Percent_Change', 'median_age', 'unemployment',
#        'total_population', 'graduate_degree', 'at_least_bachelor_s_degree',
#        'at_least_high_school_diploma', 'less_than_high_school',
#        'median_earnings_2010_dollars', 'white', 'black', 'hispanic', 'asian',
#        'farming_fishing_and_forestry_occupations',
#        'construction_extraction_maintenance_and_repair_occupations',
#        'management_professional_and_related_occupations',
#        'production_transportation_and_material_moving_occupations',
#        'sales_and_office_occupations', 'service_occupations',
#        'Dem_Votes_Percent_Change', 'Rep_Votes_Percent_Change',
#        'Poverty Percent, All Ages', 'Median Household Income', 'Age Ranges',
#        'Median Income Ranges'],
#       dtype='object')

# %%
plt.style.use('dark_background')
dem_rep_df['white'].plot(kind="hist", bins=30, alpha = 0.8, color = 'w')
plt.xlabel("White percentage")
plt.ylabel("Number of Counties")
plt.title("Percent of White\nCounties than switched from Obama to Trump")
plt.vlines(dem_rep_df['white'].mean(), ymin=0,ymax=45,colors = "y", linestyles ="dashed")

# %%
election_merged['white'].plot(kind="hist", bins=30, alpha = 0.8, color = 'w')
plt.xlabel("White percentage")
plt.ylabel("Number of Counties")
plt.title("White Percent Amongst White\n All Counties")
plt.vlines(election_merged['white'].mean(), ymin=0,ymax=450, colors = "r", linestyles ="dashed")

# %% [markdown]
# EXPLORE THE KEY SWING STATES FOR TRUMP: PA, MI, WI, OH - TO BE CONTINUED

# %%
#New DF for dem_rep in swing states
swing_state_df = dem_rep_df[(election_merged.state == "Pennsylvania") |
                                 (election_merged.state == "Michigan") |
                                 (election_merged.state == "Wisconsin") |
                                 (election_merged.state == "Ohio")]


swing_state_df.columns

#swing_state_df.head().T
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# Index(['Unnamed: 0', 'state', 'Postal Code', 'county', 'Barack Obama',
#        'Mitt Romney', 'Other_2012', 'Total Votes_2012', 'Winner_2012',
#        'Margin_2012', 'Donald Trump', 'Hillary Clinton', 'Other_2016',
#        'Total Votes_2016', 'Winner_2016', 'Margin_2016',
#        'Total_Votes_Percent_Change', 'median_age', 'unemployment',
#        'total_population', 'graduate_degree', 'at_least_bachelor_s_degree',
#        'at_least_high_school_diploma', 'less_than_high_school',
#        'median_earnings_2010_dollars', 'white', 'black', 'hispanic', 'asian',
#        'farming_fishing_and_forestry_occupations',
#        'construction_extraction_maintenance_and_repair_occupations',
#        'management_professional_and_related_occupations',
#        'production_transportation_and_material_moving_occupations',
#        'sales_and_office_occupations', 'service_occupations',
#        'Dem_Votes_Percent_Change', 'Rep_Votes_Percent_Change',
#        'Poverty Percent, All Ages', 'Median Household Income'],
#       dtype='object')

# %%
swing_state_df = swing_state_df.drop(['Barack Obama',
       'Mitt Romney', 'Other_2012', 'Total Votes_2012', 'Winner_2012',
       'Margin_2012', 'Donald Trump', 'Hillary Clinton', 'Other_2016',
       'Total Votes_2016', 'Winner_2016', 'Margin_2016',
       'Total_Votes_Percent_Change', 'median_earnings_2010_dollars', 'farming_fishing_and_forestry_occupations',
       'construction_extraction_maintenance_and_repair_occupations',
       'management_professional_and_related_occupations',
       'production_transportation_and_material_moving_occupations',
       'sales_and_office_occupations', 'service_occupations'], axis=1)

# %%
swing_state_df.columns
# Out:
# Index(['Unnamed: 0', 'state', 'Postal Code', 'county', 'median_age',
#        'unemployment', 'total_population', 'graduate_degree',
#        'at_least_bachelor_s_degree', 'at_least_high_school_diploma',
#        'less_than_high_school', 'white', 'black', 'hispanic', 'asian',
#        'Dem_Votes_Percent_Change', 'Rep_Votes_Percent_Change',
#        'Poverty Percent, All Ages', 'Median Household Income'],
#       dtype='object')

# %%
dem_rep_df['graduate_degree'].plot(kind="hist", bins=20, alpha = 0.8, color = 'c')
plt.xlabel("Percentage of People w/graduate_degree")
plt.ylabel("Number of Counties")
plt.title("Graduate_Degree \n Counties that switched from Obama to Trump")
plt.vlines(swing_state_df['graduate_degree'].mean(), ymin=0,ymax=10, colors = 'w', linestyles ="dashed")

# %%
election_merged['graduate_degree'].plot(kind="hist", bins=20, alpha = 0.8, color = 'c')
plt.xlabel("Total County Percentage of People w/graduate_degree")
plt.ylabel("Number of Counties")
plt.title("Graduate_Degree \n Counties that switched from Obama to Trump")
plt.vlines(swing_state_df['graduate_degree'].mean(), ymin=0,ymax=10, colors = 'y', linestyles ="dashed")

# %%
swing_state_df['Median Household Income'].plot(kind="hist", bins=20, alpha = 0.8, color = 'g')
plt.xlabel("Median Household Income $")
plt.ylabel("Number of Counties")
plt.title("Median Household Income\n Counties that switched from Obama to Trump")
plt.vlines(dem_rep_df['Median Household Income'].mean(), ymin=0,ymax=8, colors = 'w', linestyles ="dashed")

# %%
dem_rep_df.columns
# Out:
# Index(['Unnamed: 0', 'state', 'Postal Code', 'county', 'Barack Obama',
#        'Mitt Romney', 'Other_2012', 'Total Votes_2012', 'Winner_2012',
#        'Margin_2012', 'Donald Trump', 'Hillary Clinton', 'Other_2016',
#        'Total Votes_2016', 'Winner_2016', 'Margin_2016',
#        'Total_Votes_Percent_Change', 'median_age', 'unemployment',
#        'total_population', 'graduate_degree', 'at_least_bachelor_s_degree',
#        'at_least_high_school_diploma', 'less_than_high_school',
#        'median_earnings_2010_dollars', 'white', 'black', 'hispanic', 'asian',
#        'farming_fishing_and_forestry_occupations',
#        'construction_extraction_maintenance_and_repair_occupations',
#        'management_professional_and_related_occupations',
#        'production_transportation_and_material_moving_occupations',
#        'sales_and_office_occupations', 'service_occupations',
#        'Dem_Votes_Percent_Change', 'Rep_Votes_Percent_Change',
#        'Poverty Percent, All Ages', 'Median Household Income'],
#       dtype='object')

# %%
#swing_state_df.describe()
#Dem_Rep = len(election_df[(election_df.Winner_2012 == "Barack Obama") & (election_df.Winner_2016 == "Donald Trump")])
MI_dem_rep = len(dem_rep_df[(dem_rep_df.state == "Michigan")])
WI_dem_rep = len(dem_rep_df[(dem_rep_df.state == "Wisconsin")])
OH_dem_rep = len(dem_rep_df[(dem_rep_df.state == "Ohio")])
PA_dem_rep = len(dem_rep_df[(dem_rep_df.state == "Pennsylvania")])

# %%
#dem_rep_df1 = dem_rep_df.rename(columns = {'Median Household Income': 'MHI'})
#dem_rep_df1 = dem_rep_df.rename(columns =  {'Poverty Percent': 'poverty'})

# %%
## FOR FURTHER ANALYSIS - DO NOT NEED TO CONSIDER NOW
#Dataframes 
#MI_dem_rep_df = dem_rep_df[(dem_rep_df.state == "Michigan")]
#WI_dem_rep_df = dem_rep_df[(dem_rep_df.state == "Wisconsin")]
#OH_dem_rep_df = dem_rep_df[(dem_rep_df.state == "Ohio")]
#PA_dem_rep_df = dem_rep_df[(dem_rep_df.state == "Pennsylvania")]
#Values for white in swing counties
#MI_dem_rep_white = MI_dem_rep_df.white.mean()
#WI_dem_rep_white = WI_dem_rep_df.white.mean()
#OH_dem_rep_white = OH_dem_rep_df.white.mean()
#PA_dem_rep_white = PA_dem_rep_df.white.mean()

#Values for poverty in swing counties
#MI_dem_rep_po = MI_dem_rep_df.poverty.mean()
#WI_dem_rep_po = WI_dem_rep_df.poverty.mean()
#OH_dem_rep_po = OH_dem_rep_df.poverty.mean()
#PA_dem_rep_po = PA_dem_rep_df.poverty.mean()

#Values for MHI in swing counties
#MI_dem_rep_mhi = MI_dem_rep_df.MHI.mean()
#WI_dem_rep_mhi = WI_dem_rep_df.MHI.mean()
#OH_dem_rep_mhi = OH_dem_rep_df.MHI.mean()
#PA_dem_rep_mhi = PA_dem_rep_df.MHI.mean()

#Values for education in swing counties
#MI_dem_rep_ed = MI_dem_rep_df.at_least_bachelor_s_degree.mean()
#WI_dem_rep_ed = WI_dem_rep_df.at_least_bachelor_s_degree.mean()
#OH_dem_rep_ed = OH_dem_rep_df.at_least_bachelor_s_degree.mean()
#PA_dem_rep_ed = PA_dem_rep_df.at_least_bachelor_s_degree.mean()

#state_df = pd.DataFrame({"D2R_MI":MI_dem_rep, "D2R_WI":WI_dem_rep, "D2R_OH":OH_dem_rep, "D2R_PA":PA_dem_rep})

# %%
round(swing_state_df.describe().T, 1)
# Out:
#                               count      mean       std      min      25%  \
# Unnamed: 0                     47.0    2389.9     760.6   1249.0   1688.5
# median_age                     47.0      41.0       4.3     25.1     39.1
# unemployment                   47.0       0.1       0.0      0.1      0.1
# total_population               47.0  115692.4  154977.0   7415.0  20374.5
# graduate_degree                47.0       6.4       2.0      2.3      5.1
# at_least_bachelor_s_degree     47.0      18.7       4.7      8.5     15.4
# at_least_high_school_diploma   47.0      87.7       2.3     79.7     86.6
# less_than_high_school          47.0      12.3       2.3      7.5     10.9
# white                          47.0      89.6       6.6     71.1     85.7
# black                          47.0       3.7       4.5      0.2      0.4
# hispanic                       47.0       3.3       2.7      0.8      1.5
# asian                          47.0       0.8       0.7      0.1      0.3
# Dem_Votes_Percent_Change       47.0     -23.3       7.1    -34.8    -28.2
# Rep_Votes_Percent_Change       47.0      16.9       8.7     -5.5     11.8
# Poverty Percent, All Ages      47.0      13.2       3.6      7.6     10.9
# Median Household Income        47.0   52332.9    7057.8  35005.0  46620.5
#
#                                   50%       75%       max
# Unnamed: 0                     2302.0    3084.5    3124.0
# median_age                       40.7      43.2      48.7
# unemployment                      0.1       0.1       0.1
# total_population              60107.0  155585.0  834723.0
# graduate_degree                   6.5       7.5      11.6
# at_least_bachelor_s_degree       18.6      22.2      29.3
# at_least_high_school_diploma     87.7      89.1      92.5
# less_than_high_school            12.3      13.4      20.3
# white                            91.2      95.1      98.0
# black                             2.1       5.1      20.4
# hispanic                          2.4       4.1      10.8
# asian                             0.4       1.0       3.0
# Dem_Votes_Percent_Change        -23.8     -18.5      -2.0
# Rep_Votes_Percent_Change         17.1      22.0      34.9
# Poverty Percent, All Ages        12.4      15.0      23.8
# Median Household Income       51214.0   57950.5   65931.0

# %% [markdown]
# MAP: EXPLORE IA - THE STATE WHERE THE MOST COUNTIES FLIPPED FROM OBAMA TO TRUMP

# %%
#Geo Map for IA
geo_df = gpd.read_file('county.shp')
geo_df.plot()

# %%
#Counties in IA that flipped dem to rep
Iowa =  dem_rep_df[dem_rep_df['state'] == 'Iowa']
Iowa.head()

# %%
#IA Counties, switched from Dem to Rep X Poverty Percent, All Ages
Iowa_switch_poverty = Iowa[['state', 'county', 'Poverty Percent, All Ages']]
Iowa_switch_poverty.head()

# %%
#All Counties in IA
#Iowa_general =  dem_rep_df[dem_rep_df['state'] == 'Iowa']
#election_merged

Iowa_all =  election_merged[election_merged['state'] == 'Iowa']
Iowa_all.head()

# %%
Iowa_all_poverty = Iowa_all[['state', 'county', 'Poverty Percent, All Ages']]

Iowa_all_poverty = Iowa_all_poverty.rename(columns={"county": "COUNTY"}, inplace = True)

# %%
# Merge together data frmae for Iowa counties that switched from Obama -> Trump with geopandas data
df_mergeIowa = geo_df.merge(Iowa_all_poverty, left_on='COUNTY', right_on='COUNTY', suffixes=(False, False))

# %%
geo_df = gpd.read_file('county.shp')
geo_df.plot()

# %%
#geo_df County | Unique
geo_df.COUNTY.unique()

# %%
# Merge Iowa Geo and Iowa poverty
df_mergeIowa = geo_df.merge(Iowa_all_poverty, left_on='COUNTY', right_on='COUNTY', suffixes=(False, False))
df_mergeIowa.head()

# %%
df_mergeIowa.plot(column = 'Poverty Percent, All Ages', legend = 'TRUE')


df_mergeIowa_switch = geo_df.merge(Iowa_switch_poverty, left_on='COUNTY', right_on='COUNTY', suffixes=(False, False))
df_mergeIowa_switch.head()
